# %%
import pandas as pd

# %%
data = pd.read_csv('results.csv', index_col = 0)
data
# Out:
#           Profit  Expect_dur  Viol_prob_exact  Viol_prob_heur  \
# 100         33.0      96.274            0.097           0.100
# 200         33.0      96.486            0.097           0.105
# 300         33.0      96.486            0.096           0.097
# 400         33.0      96.486            0.094           0.108
# 500         33.0      96.073            0.095           0.118
# 600         33.0      96.016            0.086           0.088
# 700         33.0      95.421            0.094           0.100
# 800         33.0      96.913            0.095           0.091
# 900         33.0      95.754            0.089           0.093
# 1000        33.0      96.081            0.094           0.094
# expected    37.0     118.841            0.413           0.000
#
#           Viol_prob_heur_std  taken_time
# 100                    0.028       6.821
# 200                    0.021      13.713
# 300                    0.017      20.999
# 400                    0.014      26.868
# ...
